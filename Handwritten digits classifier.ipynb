# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
  nist_data = tf.keras.datasets.mnist
  (x_train, y_train), (x_test, y_test) = nist_data.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.softmax))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8228 - loss: 0.6863
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9598 - loss: 0.1325
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9747 - loss: 0.0798

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(accuracy)
print(loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9637 - loss: 0.1175
# 0.96670001745224
# 0.10714520514011383

# %%
model.save('digits.model')

# %%
for x in range(1, 6):
  img = cv.imread(f'/content/drive/MyDrive/digits/{x}.png')[:,:,0]
  img = np.invert(np.array([img]))
  prediction = model.predict(img)
  print(f'The result is probably: {np.argmax(prediction)}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# The result is probably: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The result is probably: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# The result is probably: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# The result is probably: 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# The result is probably: 5
